# %% [markdown]
# # ETL

# %% [markdown]
# ### Cargo los datasets correspondientes desde la carpeta /sources para posteriormente analizarlos, limpiarlos y guardarlos en la carpeta /Data

# %%
import pandas as pd

# %%
df_yellow_tripdata = pd.read_parquet('sources\yellow_tripdata_2024-01.parquet')
df_green_tripdata = pd.read_parquet('sources\green_tripdata_2024-01.parquet')
df_fhv_tripdata = pd.read_parquet('sources\\fhv_tripdata_2024-01.parquet')

# %%
df_yellow_tripdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2964624 entries, 0 to 2964623
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
df_yellow_tripdata.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df_yellow_tripdata.tail()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36              NaN
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52              NaN
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00              NaN
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14              NaN
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 2964619           3.18         NaN               None           107
# 2964620           4.00         NaN               None           114
# 2964621           3.33         NaN               None           211
# 2964622           3.06         NaN               None           107
# 2964623           8.10         NaN               None           138
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
df_green_tripdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56551 entries, 0 to 56550
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               56551 non-null  int32
#  1   lpep_pickup_datetime   56551 non-null  datetime64[us]
#  2   lpep_dropoff_datetime  56551 non-null  datetime64[us]
#  3   store_and_fwd_flag     53136 non-null  object
#  4   RatecodeID             53136 non-null  float64
#  5   PULocationID           56551 non-null  int32
#  6   DOLocationID           56551 non-null  int32
#  7   passenger_count        53136 non-null  float64
#  8   trip_distance          56551 non-null  float64
#  9   fare_amount            56551 non-null  float64
#  10  extra                  56551 non-null  float64
#  11  mta_tax                56551 non-null  float64
#  12  tip_amount             56551 non-null  float64
#  13  tolls_amount           56551 non-null  float64
# ...

# %%
df_green_tripdata.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2024-01-01 00:46:55   2024-01-01 00:58:25                  N
# 1         2  2024-01-01 00:31:42   2024-01-01 00:52:34                  N
# 2         2  2024-01-01 00:30:21   2024-01-01 00:49:23                  N
# 3         1  2024-01-01 00:30:20   2024-01-01 00:42:12                  N
# 4         2  2024-01-01 00:32:38   2024-01-01 00:43:37                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           236           239              1.0           1.98
# 1         1.0            65           170              5.0           6.54
# 2         1.0            74           262              1.0           3.08
# 3         1.0            74           116              1.0           2.40
# 4         1.0            74           243              1.0           5.14
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df_green_tripdata.tail()
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 56546         2  2024-01-31 20:46:00   2024-01-31 20:55:00               None
# 56547         2  2024-01-31 21:06:00   2024-01-31 21:11:00               None
# 56548         2  2024-01-31 21:36:00   2024-01-31 21:40:00               None
# 56549         2  2024-01-31 22:45:00   2024-01-31 22:51:00               None
# 56550         2  2024-01-31 22:28:00   2024-01-31 22:59:00               None
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 56546         NaN            33            25              NaN           0.00
# 56547         NaN            72            72              NaN           0.49
# 56548         NaN            72            72              NaN           0.52
# 56549         NaN            41            42              NaN           1.17
# 56550         NaN            33            91              NaN           9.27
#
# ...

# %%
df_fhv_tripdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1290116 entries, 0 to 1290115
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   dispatching_base_num    1290116 non-null  object
#  1   pickup_datetime         1290116 non-null  datetime64[us]
#  2   dropOff_datetime        1290116 non-null  datetime64[us]
#  3   PUlocationID            274816 non-null   float64
#  4   DOlocationID            1107055 non-null  float64
#  5   SR_Flag                 0 non-null        float64
#  6   Affiliated_base_number  1290116 non-null  object
# dtypes: datetime64[us](2), float64(3), object(2)
# memory usage: 68.9+ MB

# %%
df_fhv_tripdata.head()
# Out:
#   dispatching_base_num     pickup_datetime    dropOff_datetime  PUlocationID  \
# 0               B00053 2024-01-01 00:15:00 2024-01-01 02:13:00           NaN
# 1               B00111 2024-01-01 00:30:00 2024-01-01 02:37:00           NaN
# 2               B00112 2024-01-01 00:27:24 2024-01-01 01:12:05           NaN
# 3               B00112 2024-01-01 00:10:09 2024-01-01 00:25:39           NaN
# 4               B00112 2024-01-01 00:57:07 2024-01-01 01:05:04           NaN
#
#    DOlocationID  SR_Flag Affiliated_base_number
# 0           NaN      NaN                 B00014
# 1           NaN      NaN                 B00111
# 2          14.0      NaN                 B00112
# 3         133.0      NaN                 B00112
# 4          14.0      NaN                 B00112

# %%
df_fhv_tripdata.tail()
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 1290111               B03492 2024-01-31 23:51:21 2024-01-31 23:57:09
# 1290112               B03492 2024-01-31 23:05:06 2024-01-31 23:20:13
# 1290113               B03492 2024-01-31 23:49:07 2024-02-01 00:16:25
# 1290114               B03505 2024-01-31 23:04:46 2024-01-31 23:18:22
# 1290115               B03529 2024-01-31 23:45:30 2024-01-31 23:59:25
#
#          PUlocationID  DOlocationID  SR_Flag Affiliated_base_number
# 1290111           NaN          14.0      NaN                 B03492
# 1290112           NaN          21.0      NaN                 B03492
# 1290113           NaN          14.0      NaN                 B03492
# 1290114           NaN          76.0      NaN                 B03505
# 1290115           NaN          76.0      NaN                 B03404

# %%
# Función para leer y limpiar los datos PARQUET
def read_and_clean_parquet(df, file_name):    
    # Limpiar datos: eliminar duplicados
    df = df.drop_duplicates()
    
    # Limpiar datos: manejar valores faltantes
    # df = df.fillna({'some_column': 'default_value'})  # Ajusta según las columnas que manejen valores nulos
    
    # Transformaciones adicionales (ejemplo: convertir formatos de fecha)
    if 'pickup_datetime' in df.columns:
        df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
    if 'dropoff_datetime' in df.columns:
        df['dropoff_datetime'] = pd.to_datetime(df['dropoff_datetime'])
    
    # Exportar a Parquet
    df.to_parquet(file_name, index=False)

# %%
read_and_clean_parquet(df_yellow_tripdata, 'Data/cleaned_yellow_tripdata_2024-01.parquet')

# %%
read_and_clean_parquet(df_green_tripdata, 'Data/cleaned_green_tripdata_2024-01.parquet')

# %%
read_and_clean_parquet(df_fhv_tripdata, 'Data/cleaned_fhv_tripdata_2024-01.parquet')

# %% [markdown]
# ### Se analisa la informacion y estadisticas de los nuevos datasets ya limpiados

# %%
df = pd.read_parquet('Data/cleaned_yellow_tripdata_2024-01.parquet')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2964624 entries, 0 to 2964623
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.tail()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36              NaN
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52              NaN
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00              NaN
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14              NaN
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 2964619           3.18         NaN               None           107
# 2964620           4.00         NaN               None           114
# 2964621           3.33         NaN               None           211
# 2964622           3.06         NaN               None           107
# 2964623           8.10         NaN               None           138
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
summary_stats = df.describe()
print(summary_stats)
# Out:
#            VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  2.964624e+06                     2964624                     2964624
# mean   1.754204e+00  2024-01-17 00:46:36.431092  2024-01-17 01:02:13.208130
# min    1.000000e+00         2002-12-31 22:59:39         2002-12-31 23:05:41
# 25%    2.000000e+00  2024-01-09 15:59:19.750000         2024-01-09 16:16:23
# 50%    2.000000e+00  2024-01-17 10:45:37.500000  2024-01-17 11:03:51.500000
# 75%    2.000000e+00  2024-01-24 18:23:52.250000         2024-01-24 18:40:29
# max    6.000000e+00         2024-02-01 00:01:15         2024-02-02 13:56:52
# std    4.325902e-01                         NaN                         NaN
#
#        passenger_count  trip_distance    RatecodeID  PULocationID  \
# count     2.824462e+06   2.964624e+06  2.824462e+06  2.964624e+06
# mean      1.339281e+00   3.652169e+00  2.069359e+00  1.660179e+02
# min       0.000000e+00   0.000000e+00  1.000000e+00  1.000000e+00
# ...

# %%
df = pd.read_parquet('Data/cleaned_green_tripdata_2024-01.parquet')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56551 entries, 0 to 56550
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               56551 non-null  int32
#  1   lpep_pickup_datetime   56551 non-null  datetime64[us]
#  2   lpep_dropoff_datetime  56551 non-null  datetime64[us]
#  3   store_and_fwd_flag     53136 non-null  object
#  4   RatecodeID             53136 non-null  float64
#  5   PULocationID           56551 non-null  int32
#  6   DOLocationID           56551 non-null  int32
#  7   passenger_count        53136 non-null  float64
#  8   trip_distance          56551 non-null  float64
#  9   fare_amount            56551 non-null  float64
#  10  extra                  56551 non-null  float64
#  11  mta_tax                56551 non-null  float64
#  12  tip_amount             56551 non-null  float64
#  13  tolls_amount           56551 non-null  float64
# ...

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2024-01-01 00:46:55   2024-01-01 00:58:25                  N
# 1         2  2024-01-01 00:31:42   2024-01-01 00:52:34                  N
# 2         2  2024-01-01 00:30:21   2024-01-01 00:49:23                  N
# 3         1  2024-01-01 00:30:20   2024-01-01 00:42:12                  N
# 4         2  2024-01-01 00:32:38   2024-01-01 00:43:37                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           236           239              1.0           1.98
# 1         1.0            65           170              5.0           6.54
# 2         1.0            74           262              1.0           3.08
# 3         1.0            74           116              1.0           2.40
# 4         1.0            74           243              1.0           5.14
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df.tail()
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 56546         2  2024-01-31 20:46:00   2024-01-31 20:55:00               None
# 56547         2  2024-01-31 21:06:00   2024-01-31 21:11:00               None
# 56548         2  2024-01-31 21:36:00   2024-01-31 21:40:00               None
# 56549         2  2024-01-31 22:45:00   2024-01-31 22:51:00               None
# 56550         2  2024-01-31 22:28:00   2024-01-31 22:59:00               None
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 56546         NaN            33            25              NaN           0.00
# 56547         NaN            72            72              NaN           0.49
# 56548         NaN            72            72              NaN           0.52
# 56549         NaN            41            42              NaN           1.17
# 56550         NaN            33            91              NaN           9.27
#
# ...

# %%
summary_stats = df.describe()
print(summary_stats)
# Out:
#            VendorID        lpep_pickup_datetime       lpep_dropoff_datetime  \
# count  56551.000000                       56551                       56551
# mean       1.870241  2024-01-16 21:13:00.132941  2024-01-16 21:31:10.415660
# min        1.000000         2023-12-31 14:38:47         2023-12-31 14:46:45
# 25%        2.000000         2024-01-09 10:57:45         2024-01-09 11:20:21
# 50%        2.000000         2024-01-17 07:20:09         2024-01-17 07:34:18
# 75%        2.000000         2024-01-24 15:28:22         2024-01-24 15:40:44
# max        2.000000         2024-01-31 23:57:29         2024-02-01 19:17:30
# std        0.336041                         NaN                         NaN
#
#          RatecodeID  PULocationID  DOLocationID  passenger_count  \
# count  53136.000000  56551.000000  56551.000000     53136.000000
# mean       1.151611     96.077594    140.499850         1.309169
# min        1.000000      1.000000      1.000000         0.000000
# ...

# %%
df = pd.read_parquet('Data/cleaned_fhv_tripdata_2024-01.parquet')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1287590 entries, 0 to 1287589
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   dispatching_base_num    1287590 non-null  object
#  1   pickup_datetime         1287590 non-null  datetime64[us]
#  2   dropOff_datetime        1287590 non-null  datetime64[us]
#  3   PUlocationID            274706 non-null   float64
#  4   DOlocationID            1106942 non-null  float64
#  5   SR_Flag                 0 non-null        float64
#  6   Affiliated_base_number  1287590 non-null  object
# dtypes: datetime64[us](2), float64(3), object(2)
# memory usage: 68.8+ MB

# %%
df.head()
# Out:
#   dispatching_base_num     pickup_datetime    dropOff_datetime  PUlocationID  \
# 0               B00053 2024-01-01 00:15:00 2024-01-01 02:13:00           NaN
# 1               B00111 2024-01-01 00:30:00 2024-01-01 02:37:00           NaN
# 2               B00112 2024-01-01 00:27:24 2024-01-01 01:12:05           NaN
# 3               B00112 2024-01-01 00:10:09 2024-01-01 00:25:39           NaN
# 4               B00112 2024-01-01 00:57:07 2024-01-01 01:05:04           NaN
#
#    DOlocationID  SR_Flag Affiliated_base_number
# 0           NaN      NaN                 B00014
# 1           NaN      NaN                 B00111
# 2          14.0      NaN                 B00112
# 3         133.0      NaN                 B00112
# 4          14.0      NaN                 B00112

# %%
df.tail()
# Out:
#         dispatching_base_num     pickup_datetime    dropOff_datetime  \
# 1287585               B03492 2024-01-31 23:51:21 2024-01-31 23:57:09
# 1287586               B03492 2024-01-31 23:05:06 2024-01-31 23:20:13
# 1287587               B03492 2024-01-31 23:49:07 2024-02-01 00:16:25
# 1287588               B03505 2024-01-31 23:04:46 2024-01-31 23:18:22
# 1287589               B03529 2024-01-31 23:45:30 2024-01-31 23:59:25
#
#          PUlocationID  DOlocationID  SR_Flag Affiliated_base_number
# 1287585           NaN          14.0      NaN                 B03492
# 1287586           NaN          21.0      NaN                 B03492
# 1287587           NaN          14.0      NaN                 B03492
# 1287588           NaN          76.0      NaN                 B03505
# 1287589           NaN          76.0      NaN                 B03404

# %%
summary_stats = df.describe()
print(summary_stats)
# Out:
#                   pickup_datetime            dropOff_datetime   PUlocationID  \
# count                     1287590                     1287590  274706.000000
# mean   2024-01-16 23:05:19.300047  2024-01-16 23:39:30.736740     134.288902
# min           2024-01-01 00:00:01         2024-01-01 00:03:56       1.000000
# 25%    2024-01-09 12:51:47.750000  2024-01-09 13:17:52.250000      72.000000
# 50%           2024-01-17 09:15:00         2024-01-17 09:43:00     133.000000
# 75%           2024-01-24 13:09:21  2024-01-24 13:42:13.750000     206.000000
# max           2024-01-31 23:59:59         2025-01-25 06:35:00     265.000000
# std                           NaN                         NaN      74.414899
#
#        DOlocationID  SR_Flag
# count  1.106942e+06      0.0
# mean   1.351779e+02      NaN
# min    1.000000e+00      NaN
# 25%    6.900000e+01      NaN
# 50%    1.320000e+02      NaN
# 75%    2.120000e+02      NaN
# max    2.650000e+02      NaN
# std    7.888913e+01      NaN

# %% [markdown]
# ### Por una cuestion de tamaño que GitHub recomienda no subir archivos que pesen mas de 50mb, dividimos el archivo en 5 partes para luego en el EDA unirlos y seguir trabajando sin problemas

# %%
import numpy as np

# Leer el archivo parquet
df = pd.read_parquet('Data/cleaned_yellow_tripdata_2024-01.parquet')

# Número de partes en las que quieres dividir el DataFrame
num_parts = 5  # Cambia esto según el número de partes que desees

# Dividir el DataFrame en partes iguales
chunks = np.array_split(df, num_parts)

# Guardar cada parte en un archivo parquet separado
for i, chunk in enumerate(chunks):
    chunk.to_parquet(f'Data/cleaned_yellow_tripdata_part_{i+1}.parquet', index=False)
# Out:
# c:\Users\Familia\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
import os

# Verifica los archivos generados
for filename in os.listdir('Data'):
    if filename.startswith('cleaned_yellow_tripdata_part_') and filename.endswith('.parquet'):
        print(filename)
# Out:
# cleaned_yellow_tripdata_part_1.parquet
# cleaned_yellow_tripdata_part_2.parquet
# cleaned_yellow_tripdata_part_3.parquet
# cleaned_yellow_tripdata_part_4.parquet
# cleaned_yellow_tripdata_part_5.parquet

# %%
# Eliminar el archivo
if os.path.exists('Data/cleaned_yellow_tripdata_2024-01.parquet'):
    os.remove('Data/cleaned_yellow_tripdata_2024-01.parquet')
    print(f'Archivo "Data/cleaned_yellow_tripdata_2024-01.parquet" eliminado exitosamente.')
else:
    print(f'El archivo "Data/cleaned_yellow_tripdata_2024-01.parquet" no existe.')
# Out:
# El archivo "Data/cleaned_yellow_tripdata_2024-01.parquet" no existe.
