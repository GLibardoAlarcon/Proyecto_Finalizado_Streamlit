# %%
import pandas as pd

# %%
df_eafcs = pd.read_parquet('../Data/df_eafcs.parquet')

# %%
df_eafcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Fuel Type Code  188 non-null    object
#  1   Station Name    188 non-null    object
#  2   Street Address  188 non-null    object
#  3   City            188 non-null    object
#  4   State           188 non-null    object
#  5   Latitude        188 non-null    float64
#  6   Longitude       188 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 10.4+ KB

# %%
df_eafcs.head()
# Out:
#   Fuel Type Code                                       Station Name  \
# 0            CNG          Clean Energy - Greenpoint - National Grid
# 1            CNG               Con Edison - Van Nest Service Center
# 2            CNG          Con Edison - College Point Service Center
# 3            CNG                                          Bronx Zoo
# 4            CNG  Trillium - MTA New York City Transit - West Fa...
#
#        Street Address      City State   Latitude  Longitude
# 0     287 Maspeth Ave  Brooklyn    NY  40.718037 -73.932309
# 1  1615 Bronxdale Ave     Bronx    NY  40.844188 -73.861572
# 2     124-15 31st Ave    Queens    NY  40.769623 -73.843069
# 3  2300 Southern Blvd     Bronx    NY  40.850018 -73.878128
# 4     1100 E 177th St     Bronx    NY  40.838672 -73.877566

# %%
df_vfed = pd.read_parquet('../Data/df_vfed.parquet')

# %%
df_vfed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40544 entries, 0 to 40543
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    40544 non-null  int64
#  1   Manufacturer            40544 non-null  object
#  2   Model                   40544 non-null  object
#  3   Miles per gallon (mpg)  40544 non-null  float64
#  4   CO2 (p/mile)            40544 non-null  float64
#  5   FuelCost                40544 non-null  float64
#  6   FuelCostA               40544 non-null  float64
#  7   Fuel                    40544 non-null  object
#  8   Category                40544 non-null  object
#  9   atvType                 4264 non-null   object
#  10  Alternative Fuel        40544 non-null  object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 3.4+ MB

# %%
df_vfed.head()
# Out:
#    Year Manufacturer                          Model  Miles per gallon (mpg)  \
# 0  2017          BMW                       M6 Coupe                    15.0
# 1  2017          BMW                   X3 sDrive28i                    21.0
# 2  2016     Infiniti                 Q50S Red Sport                    20.0
# 3  2017         MINI  John Cooper Works Convertible                    24.0
# 4  2017          Kia                      Sedona SX                    18.0
#
#    CO2 (p/mile)  FuelCost  FuelCostA              Fuel  \
# 0         519.0    3850.0        0.0  Premium Gasoline
# 1         374.0    2700.0        0.0  Premium Gasoline
# 2         402.0    2950.0        0.0  Premium Gasoline
# 3         327.0    2400.0        0.0  Premium Gasoline
# 4         433.0    2550.0        0.0  Regular Gasoline
#
#                           Category atvType Alternative Fuel
# 0                  Subcompact Cars    None               No
# ...

# %%
df_costo_operacional_vehiculos_clean = pd.read_csv('../Data/costo_operacional_vehiculos_clean.csv')

# %%
df_costo_operacional_vehiculos_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4625 entries, 0 to 4624
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Manuf          4625 non-null   object
#  1   Model          4625 non-null   object
#  2   Desc           4625 non-null   object
#  3   Fuel_Type      4625 non-null   object
#  4   Fuel_Cost      4625 non-null   float64
#  5   Electric_Cost  4625 non-null   float64
#  6   Total_Cost     4625 non-null   float64
#  7   Noise_Level    4625 non-null   float64
# dtypes: float64(4), object(4)
# memory usage: 289.2+ KB

# %%
df_costo_operacional_vehiculos_clean.head()
# Out:
#     Manuf Model                         Desc Fuel_Type    Fuel_Cost  \
# 0  ABARTH   595  595 1.4 145 BHP Convertible    Petrol  1547.432488
# 1  ABARTH   595  595 1.4 145 BHP Convertible    Petrol  1633.800813
# 2  ABARTH   595    595 1.4 145 BHP Hatchback    Petrol  1547.432488
# 3  ABARTH   595    595 1.4 145 BHP Hatchback    Petrol  1633.800813
# 4  ABARTH   595          595 1.4 TJET 145bhp    Petrol  1461.863870
#
#    Electric_Cost   Total_Cost  Noise_Level
# 0            0.0  1547.432488         73.5
# 1            0.0  1633.800813         73.5
# 2            0.0  1547.432488         73.5
# 3            0.0  1633.800813         73.5
# 4            0.0  1461.863870         74.0

# %%
df_yellow_tripdata = pd.read_parquet('../Data/yellow_tripdata.parquet')

# %%
df_yellow_tripdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2824462 entries, 0 to 2824461
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   pickup_datetime        datetime64[us]
#  2   dropoff_datetime       datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
#  19  trip_duration          float64
#  20  day_of_week            object
# ...

# %%
df_fhv_tripdata = pd.read_parquet('../Data/fhv_tripdata.parquet')

# %%
df_fhv_tripdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 263175 entries, 111 to 1290097
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   dispatching_base_num    263175 non-null  object
#  1   pickup_datetime         263175 non-null  datetime64[us]
#  2   dropoff_datetime        263175 non-null  datetime64[us]
#  3   PUlocationID            263175 non-null  float64
#  4   DOlocationID            263175 non-null  float64
#  5   SR_Flag                 263175 non-null  float64
#  6   Affiliated_base_number  263175 non-null  object
#  7   trip_duration           263175 non-null  float64
#  8   day_of_week             263175 non-null  object
#  9   duration_binned         262503 non-null  category
#  10  hour_of_day             263175 non-null  int32
# dtypes: category(1), datetime64[us](2), float64(4), int32(1), object(3)
# memory usage: 21.3+ MB

# %%
df_fhv_tripdata
# Out:
#         dispatching_base_num     pickup_datetime    dropoff_datetime  \
# 111                   B00171 2024-01-01 00:52:00 2024-01-01 00:57:00
# 118                   B00254 2024-01-01 00:30:55 2024-01-01 00:46:58
# 119                   B00254 2024-01-01 00:28:52 2024-01-01 00:38:15
# 120                   B00254 2024-01-01 00:40:28 2024-01-01 01:20:33
# 121                   B00254 2024-01-01 00:37:30 2024-01-01 00:43:32
# ...                      ...                 ...                 ...
# 1290088               B03284 2024-01-31 23:55:47 2024-02-01 01:07:28
# 1290089               B03284 2024-01-31 23:34:36 2024-02-01 00:02:27
# 1290090               B03285 2024-01-31 23:13:46 2024-01-31 23:25:42
# 1290096               B03320 2024-01-31 23:58:00 2024-02-01 00:22:00
# 1290097               B03320 2024-01-31 23:01:00 2024-02-01 00:17:00
#
#          PUlocationID  DOlocationID  SR_Flag Affiliated_base_number  \
# 111             151.0          75.0      0.0                 B00256
# ...

# %%
df_green_tripdata = pd.read_parquet('../Data/green_tripdata.parquet')

# %%
df_green_tripdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53133 entries, 0 to 53135
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               53133 non-null  int32
#  1   pickup_datetime        53133 non-null  datetime64[us]
#  2   dropoff_datetime       53133 non-null  datetime64[us]
#  3   store_and_fwd_flag     53133 non-null  object
#  4   RatecodeID             53133 non-null  float64
#  5   PULocationID           53133 non-null  int32
#  6   DOLocationID           53133 non-null  int32
#  7   passenger_count        53133 non-null  float64
#  8   trip_distance          53133 non-null  float64
#  9   fare_amount            53133 non-null  float64
#  10  extra                  53133 non-null  float64
#  11  mta_tax                53133 non-null  float64
#  12  tip_amount             53133 non-null  float64
#  13  tolls_amount           53133 non-null  float64
# ...

# %%
df_vehicle_counts_cleaned = pd.read_parquet('../Data/vehicle_counts_cleaned.parquet')

# %%
df_vehicle_counts_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10030 entries, 0 to 18092
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Roadway Name    10030 non-null  object
#  1   Veh Class Type  10030 non-null  object
#  2   Date            10030 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 313.4+ KB

# %%
df_vehicle_counts_cleaned.head()
# Out:
#   Roadway Name Veh Class Type       Date
# 0    34 Avenue           Auto 2014-10-29
# 1    34 Avenue          Taxis 2014-10-29
# 2    34 Avenue     Commercial 2014-10-29
# 3    34 Avenue   Medium Truck 2014-10-29
# 4    34 Avenue    Heavy Truck 2014-10-29

# %%
df_vehicle_counts_cleaned_copy = pd.read_parquet('../Data/vehicle_counts_cleaned copy.parquet')

# %%
df_vehicle_counts_cleaned_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10030 entries, 0 to 18092
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Roadway Name    10030 non-null  object
#  1   Veh Class Type  10030 non-null  object
#  2   Date            10030 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 313.4+ KB

# %%
df_vehicle_counts_cleaned_copy.head()
# Out:
#   Roadway Name Veh Class Type       Date
# 0    34 Avenue           Auto 2014-10-29
# 1    34 Avenue          Taxis 2014-10-29
# 2    34 Avenue     Commercial 2014-10-29
# 3    34 Avenue   Medium Truck 2014-10-29
# 4    34 Avenue    Heavy Truck 2014-10-29

# %%
df_energy_clean = pd.read_csv('../Data/energy_clean.csv')

# %%
df_energy_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             240 non-null    object
#  1   Energy_type         240 non-null    object
#  2   Year                240 non-null    int64
#  3   Energy_consumption  240 non-null    float64
#  4   CO2_emission        240 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 9.5+ KB

# %%
df_energy_clean.head()
# Out:
#          Country                Energy_type  Year  Energy_consumption  \
# 0  United States           all_energy_types  1980           78.021113
# 1  United States                       coal  1980           15.422809
# 2  United States                natural_gas  1980           20.235459
# 3  United States  petroleum_n_other_liquids  1980           34.158965
# 4  United States                    nuclear  1980            2.739169
#
#    CO2_emission
# 0   4946.627130
# 1   1409.790188
# 2   1081.593377
# 3   2455.243565
# 4      0.000000

# %%
datos_meteorologicos_limpios = pd.read_parquet('../Data/datos_meteorologicos_limpios.parquet')

# %%
datos_meteorologicos_limpios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17568 entries, 0 to 17567
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   time                 17568 non-null  datetime64[ns]
#  1   temperature_2m (°C)  17568 non-null  object
#  2   rain (mm)            17568 non-null  object
#  3   is_day ()            17568 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 549.1+ KB

# %%
datos_meteorologicos_limpios.head()
# Out:
#                  time temperature_2m (°C) rain (mm) is_day ()
# 0 2022-06-30 00:00:00                17.7      0.10         1
# 1 2022-06-30 01:00:00                18.2      0.00         1
# 2 2022-06-30 02:00:00                19.4      0.00         1
# 3 2022-06-30 03:00:00                20.7      0.00         1
# 4 2022-06-30 04:00:00                21.5      0.00         1

# %%
df_datos_geograficos_limpios = pd.read_parquet('../Data/datos_geograficos_limpios.parquet')

# %%
df_datos_geograficos_limpios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   latitude               1 non-null      float64
#  1   longitude              1 non-null      float64
#  2   elevation              1 non-null      float64
#  3   utc_offset_seconds     1 non-null      int32
#  4   timezone               1 non-null      object
#  5   timezone_abbreviation  1 non-null      object
# dtypes: float64(3), int32(1), object(2)
# memory usage: 172.0+ bytes

# %%
df_datos_geograficos_limpios.head()
# Out:
#    latitude  longitude  elevation  utc_offset_seconds          timezone  \
# 0  52.54833  13.407822       38.0              -14400  America/New_York
#
#   timezone_abbreviation
# 0                   EDT

# %%
df_Calidad_aireL = pd.read_parquet('../Data/Calidad_aireL.parquet')

# %%
df_Calidad_aireL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16218 entries, 0 to 16217
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   indicator_id    16218 non-null  int64
#  1   name            16218 non-null  object
#  2   measure         16218 non-null  object
#  3   geo_type_name   16218 non-null  object
#  4   geo_join_id     16218 non-null  int64
#  5   data_value      16218 non-null  float64
#  6   geo_place_name  16218 non-null  object
#  7   measure_info    16218 non-null  object
#  8   time_period     16218 non-null  object
#  9   unique_id       16218 non-null  int64
#  10  Date            16218 non-null  object
#  11  Year            16218 non-null  int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1.5+ MB

# %%
df_Calidad_aireL.head()
# Out:
#    indicator_id                                         name  \
# 0           643                Annual vehicle miles traveled
# 1           652  Cardiac and respiratory deaths due to Ozone
# 2           652  Cardiac and respiratory deaths due to Ozone
# 3           647            Outdoor Air Toxics - Formaldehyde
# 4           647            Outdoor Air Toxics - Formaldehyde
#
#                         measure geo_type_name  geo_join_id  data_value  \
# 0                 million miles            CD          107        50.0
# 1         Estimated annual rate       Borough            5         7.8
# 2         Estimated annual rate         UHF42          504         7.5
# 3  Annual average concentration       Borough            5         2.3
# 4  Annual average concentration         UHF42          211         3.1
#
#               geo_place_name measure_info time_period  unique_id        Date  \
# 0      Upper West Side (CD7)      per km2        2016     325247  2016-01-01
# ...

# %% [markdown]
# <a id="air_quality_cleaned"><b>air_quality_cleaned</b></a>

# %%
df_air_quality_cleaned = pd.read_parquet('../Data/air_quality_cleaned.parquet')

# %%
df_air_quality_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15406 entries, 0 to 18024
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            15406 non-null  object
#  1   Measure         15406 non-null  object
#  2   Geo Place Name  15397 non-null  object
#  3   Time Period     15406 non-null  object
#  4   Data Value      15406 non-null  float64
#  5   Year            15406 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 842.5+ KB

# %%
df_air_quality_cleaned.head()
# Out:
#                                     Name         Measure  \
# 0  Boiler Emissions- Total SO2 Emissions  Number per km2
# 1  Boiler Emissions- Total SO2 Emissions  Number per km2
# 2                Fine particles (PM 2.5)            Mean
# 3                Fine particles (PM 2.5)            Mean
# 4                Fine particles (PM 2.5)            Mean
#
#             Geo Place Name          Time Period  Data Value       Year
# 0         Southeast Queens                 2015         0.3 2015-01-01
# 1  Bensonhurst - Bay Ridge                 2015         1.2 2015-01-01
# 2  Bensonhurst - Bay Ridge  Annual Average 2012         8.6 2012-01-01
# 3         Southeast Queens  Annual Average 2012         8.0 2012-01-01
# 4         Southeast Queens          Summer 2022         6.1 2022-01-01

# %%
car_resale_prices_clean = pd.read_csv('../Data/car_resale_prices_clean.csv')

# %%
car_resale_prices_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17446 entries, 0 to 17445
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Full_Name          17446 non-null  object
#  1   Registered_Year    17377 non-null  float64
#  2   Transmission_Type  17446 non-null  object
#  3   Fuel_Type          17446 non-null  object
#  4   Max_Power          17344 non-null  object
#  5   Resale_Price       17212 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 817.9+ KB

# %%
car_resale_prices_clean.head()
# Out:
#                       Full_Name  Registered_Year Transmission_Type Fuel_Type  \
# 0  2017 Maruti Baleno 1.2 Alpha           2017.0            Manual    Petrol
# 1            2018 Tata Hexa XTA           2018.0         Automatic    Diesel
# 2   2015 Maruti Swift Dzire VXI           2015.0            Manual    Petrol
# 3   2015 Maruti Swift Dzire VXI           2015.0            Manual    Petrol
# 4    2009 Hyundai i10 Magna 1.1           2009.0            Manual    Petrol
#
#    Max_Power  Resale_Price
# 0    83.1bhp        6540.0
# 1  153.86bhp       12000.0
# 2   83.14bhp        5400.0
# 3   83.14bhp        5400.0
# 4   68.05bhp        1920.0
